# %%
import pandas as pandas
import numpy as np

# %% [markdown]
# # Q1

# %% [markdown]
# Pandas is an open-source Python library used for data manipulation and analysis. It provides powerful data structures like Series and DataFrame to store and process structured data efficiently.
# Role in Data Analysis:
# Reading data from CSV, Excel, SQL, etc.
# Cleaning and preprocessing data.
# Handling missing values.
# Filtering, sorting, and grouping data.
# Performing statistical analysis.
# Role in Machine Learning:
# Preparing datasets before training models.
# Feature selection and transformation.
# Handling missing and duplicate values.
# Converting categorical data into numerical form.
# Creating clean datasets for ML algorithms.

# %% [markdown]
# # Q2

# %% [markdown]
# (A) Series and DataFrame
# Series:
# A Series is a one-dimensional (1D) data structure in Pandas that stores data in a single column with an index.
# DataFrame:
# A DataFrame is a two-dimensional (2D) data structure in Pandas that stores data in rows and columns, similar to a table or spreadsheet.
#
# (b) loc[] and iloc[]
# loc[]:
# loc[] is used to select data using row and column labels (names).
# iloc[]:
# iloc[] is used to select data using integer positions (index numbers) of rows and columns.

# %% [markdown]
# # Q3

# %%
import pandas as pd

data = {
    'Name': ['Amit', 'Neha', 'Rahul', 'Sneha'],
    'Age': [20, 21, 19, 22],
    'Marks': [85, 90, 78, 88]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#     Name  Age  Marks
# 0   Amit   20     85
# 1   Neha   21     90
# 2  Rahul   19     78
# 3  Sneha   22     88

# %%
print(df.head(2))
print(df[['Name', 'Marks']])
df['Result'] = ['Pass', 'Pass', 'Pass', 'Pass']
print(df)
print(df[df['Marks'] > 80])
# Out:
#    Name  Age  Marks
# 0  Amit   20     85
# 1  Neha   21     90
#     Name  Marks
# 0   Amit     85
# 1   Neha     90
# 2  Rahul     78
# 3  Sneha     88
#     Name  Age  Marks Result
# 0   Amit   20     85   Pass
# 1   Neha   21     90   Pass
# 2  Rahul   19     78   Pass
# 3  Sneha   22     88   Pass
#     Name  Age  Marks Result
# 0   Amit   20     85   Pass
# 1   Neha   21     90   Pass
# 3  Sneha   22     88   Pass

# %% [markdown]
# # Q4

# %%
import pandas as pd
import numpy as np

data = {
    'Name': ['A', 'B', 'C', 'D'],
    'Age': [25, np.nan, 27, 24],
    'Salary': [30000, 40000, np.nan, 35000]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#   Name   Age   Salary
# 0    A  25.0  30000.0
# 1    B   NaN  40000.0
# 2    C  27.0      NaN
# 3    D  24.0  35000.0

# %%
print(df.isnull())
print(df.isnull().sum())
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Salary'].fillna(df['Salary'].median(), inplace=True)
print(df)
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2  False  False    True
# 3  False  False   False
# Name      0
# Age       1
# Salary    1
# dtype: int64
#   Name   Age   Salary
# 0    A  25.0  30000.0
# 1    B   NaN  40000.0
# 2    C  27.0      NaN
# 3    D  24.0  35000.0
# C:\Users\abc\AppData\Local\Temp\ipykernel_22236\3657836727.py:3: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# ...

# %% [markdown]
# # Q5

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\abc\OneDrive\Desktop\anand collage 45 days traning\assignment\iris.csv")
print(df.info())
print("Rows and Columns:", df.shape)
print("Average Sepal Length:",
      df['sepal_length'].mean())
print(df['species'].unique())
print(df.describe())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    str
#  5   species_id    150 non-null    int64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB
# None
# Rows and Columns: (150, 6)
# Average Sepal Length: 5.843333333333334
# <StringArray>
# ['setosa', 'versicolor', 'virginica']
# Length: 3, dtype: str
#        sepal_length  sepal_width  petal_length  petal_width  species_id
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667    2.000000
# std        0.828066     0.433594      1.764420     0.763161    0.819232
# ...
